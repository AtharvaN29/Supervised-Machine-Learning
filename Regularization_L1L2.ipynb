# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('./datasets_for_tuts/Melbourne_housing_FULL.csv')
dataset.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
dataset.shape
# Out:
# (12076, 12634)

# %%
dataset.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
cols_to_fill_zero = ['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']
dataset[cols_to_fill_zero] = dataset[cols_to_fill_zero].fillna(0)
dataset['Landsize'] = dataset['Landsize'].fillna(dataset.Landsize.mean())
dataset['BuildingArea'] = dataset['BuildingArea'].fillna(dataset.BuildingArea.mean())

# %%
dataset.dropna(inplace=True)

# %%
dataset.shape
# Out:
# (12076, 12634)

# %%
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
dataset.head()
# Out:
#     Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 2       2  1035000.0       2.5    3067.0       2.0       1.0  0.0     156.0
# 4       3  1465000.0       2.5    3067.0       3.0       2.0  0.0     134.0
# 6       4  1600000.0       2.5    3067.0       3.0       1.0  2.0     120.0
# 11      3  1876000.0       2.5    3067.0       4.0       2.0  0.0     245.0
# 14      2  1636000.0       2.5    3067.0       2.0       1.0  2.0     256.0
#
#     BuildingArea  YearBuilt  ...  CouncilArea_Wyndham City Council  \
# 2           79.0     1900.0  ...                             False
# 4          150.0     1900.0  ...                             False
# 6          142.0     2014.0  ...                             False
# 11         210.0     1910.0  ...                             False
# 14         107.0     1890.0  ...                             False
#
#     CouncilArea_Yarra City Council  CouncilArea_Yarra Ranges Shire Council  \
# 2                             True                                   False
# 4                             True                                   False
# 6                             True                                   False
# 11                            True                                   False
# 14                            True                                   False
#
#     Regionname_Eastern Victoria  Regionname_Northern Metropolitan  \
# 2                         False                              True
# 4                         False                              True
# 6                         False                              True
# 11                        False                              True
# 14                        False                              True
#
#     Regionname_Northern Victoria  Regionname_South-Eastern Metropolitan  \
# 2                          False                                  False
# 4                          False                                  False
# 6                          False                                  False
# 11                         False                                  False
# 14                         False                                  False
#
#     Regionname_Southern Metropolitan  Regionname_Western Metropolitan  \
# 2                              False                            False
# 4                              False                            False
# 6                              False                            False
# 11                             False                            False
# 14                             False                            False
#
#     Regionname_Western Victoria
# 2                         False
# 4                         False
# 6                         False
# 11                        False
# 14                        False
#
# [5 rows x 12634 columns]

# %%
X = dataset.drop('Price', axis=1)
y = dataset['Price']

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(train_X, train_y)
# Out:
# ----------------------------------------------------------------
# KeyboardInterrupt              Traceback (most recent call last)
# Cell In[19], line 2
#       1 from sklearn.linear_model import LinearRegression
# ----> 2 reg = LinearRegression().fit(train_X, train_y)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:651, in LinearRegression.fit(self, X, y, sample_weight)
#     649         self.coef_ = np.vstack([out[0] for out in outs])
#     650 else:
# --> 651     self.coef_, _, self.rank_, self.singular_ = linalg.lstsq(X, y)
#     652     self.coef_ = self.coef_.T
#     654 if y.ndim == 1:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\linalg\_basic.py:1294, in lstsq(a, b, cond, overwrite_a, overwrite_b, check_finite, lapack_driver)
#    1291 if info < 0:
#    1292     raise ValueError('illegal value in %d-th argument of internal %s'
#    1293                      % (-info, lapack_driver))
# -> 1294 resids = np.asarray([], dtype=x.dtype)
#    1295 if m > n:
#    1296     x1 = x[:n]
#
# KeyboardInterrupt:

# %%
reg.score(test_X, test_y)
